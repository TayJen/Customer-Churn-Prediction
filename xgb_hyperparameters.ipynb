# %%
import pandas as pd
import numpy as np
import time
import warnings

from sklearn.metrics import classification_report, f1_score, roc_auc_score
import xgboost as xgb
from sklearn.model_selection import train_test_split

# hyperparameter tuning
from hyperopt import fmin, tpe, hp, SparkTrials, STATUS_OK
from hyperopt.pyll import scope

# model/grid search tracking
import mlflow

warnings.filterwarnings("ignore")

# %%
from preprocessing import convert_data, engineer_features, select_features
from imblearn.combine import SMOTEENN
from collections import Counter


path = 'data\\train.csv'
df = pd.read_csv(path)
df = convert_data(df)
df = engineer_features(df)
df = select_features(df)

X = df.drop('churn', axis=1)
y = df.churn

oversample = SMOTEENN()
print(Counter(y))
X, y = oversample.fit_resample(X, y)
print(Counter(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=True, random_state=59)

(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Counter({0: 3597, 1: 598})
# Counter({1: 3000, 0: 2118})
# ((4350, 16), (4350,), (768, 16), (768,))

# %% [markdown]
# We can do without scaling, because the model is not linear

# %%
X_train
# Out:
#       account_length  international_plan  number_vmail_messages  \
# 1292             122                   0                     29
# 782              123                   0                     39
# 4250              95                   0                      0
# 4096              77                   0                      0
# 3840             111                   0                      0
# ...              ...                 ...                    ...
# 1887             143                   0                      0
# 3893              48                   0                      0
# 1387             106                   0                     29
# 663              106                   0                      0
# 4273             114                   0                      0
#
#       total_intl_minutes  total_intl_calls  number_customer_service_calls  \
# 1292            8.400000                 6                              3
# 782            15.400000                 7                              1
# 4250           11.383436                 2                              1
# 4096            8.628306                 9                              1
# 3840           10.619981                 2                              3
# ...                  ...               ...                            ...
# 1887           17.200000                 5                              1
# 3893           12.847273                 5                              1
# 1387            8.100000                 3                              1
# 663             9.600000                 2                              0
# 4273           12.048958                 4                              3
#
#       total_minutes  total_calls  area_code_area_code_408  \
# 1292     631.600000          271                        1
# 782      624.400000          322                        1
# 4250     750.134144          326                        0
# 4096     733.110093          296                        0
# 3840     492.912077          267                        0
# ...             ...          ...                      ...
# 1887     561.900000          277                        0
# 3893     725.161154          266                        1
# 1387     517.000000          335                        1
# 663      685.300000          371                        1
# 4273     717.320733          242                        0
#
#       area_code_area_code_415  area_code_area_code_510  state_other  \
# 1292                        0                        0            1
# 782                         0                        0            1
# 4250                        0                        0            1
# 4096                        0                        0            0
# 3840                        0                        1            0
# ...                       ...                      ...          ...
# 1887                        1                        0            1
# 3893                        0                        0            0
# 1387                        0                        0            1
# 663                         0                        0            1
# 4273                        0                        0            1
#
#       avg_mt_charge  avg_call_charge  avg_intl_call_charge  both_plans
# 1292       0.521148         0.234613              0.378333           0
# 782        0.582927         0.222671              0.594286           0
# 4250       0.793959         0.232174              2.259286           0
# 4096       0.943212         0.247111              0.269163           0
# 3840       0.434861         0.181452              1.399703           0
# ...             ...              ...                   ...         ...
# 1887       0.467203         0.241191              0.928000           0
# 3893       1.558419         0.280735              0.659892           0
# 1387       0.395000         0.124985              0.730000           0
# 663        0.594623         0.169892              1.295000           0
# 4273       0.629211         0.295589              0.804744           0
#
# [4350 rows x 16 columns]

# %%
search_space = {
    'learning_rate': hp.loguniform('learning_rate', -7, 0),
    'max_depth': scope.int(hp.uniform('max_depth', 1, 100)),
    'min_child_weight': hp.loguniform('min_child_weight', -2, 3),
    'subsample': hp.uniform('subsample', 0.5, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
    'gamma': hp.loguniform('gamma', -10, 10),
    'alpha': hp.loguniform('alpha', -10, 10),
    'lambda': hp.loguniform('lambda', -10, 10),
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'seed': 59,
}

# %%
train = xgb.DMatrix(data=X_train, label=y_train)
test = xgb.DMatrix(data=X_test, label=y_test)

# %%
def train_model(params):
    # With MLflow autologging, hyperparameters and the trained model are automatically logged to MLflow.
    mlflow.xgboost.autolog(silent=True)

    # However, we can log additional information by using an MLFlow tracking context manager 
    with mlflow.start_run(nested=True):

        # Train model and record run time
        start_time = time.time()
        booster = xgb.train(params=params, dtrain=train, num_boost_round=5000, evals=[(test, "test")],
                            early_stopping_rounds=50, verbose_eval=False)
        run_time = time.time() - start_time
        mlflow.log_metric('runtime', run_time)

        # Record AUC as primary loss for Hyperopt to minimize
        predictions_test = booster.predict(test)
        f1score = f1_score(y_test, predictions_test)
        mlflow.log_metric('f1-score-mine', f1score)
        
        auc_score = roc_auc_score(y_test, predictions_test)

        # Set the loss to -1*f1_score so fmin maximizes the auc_score
        return {'status': STATUS_OK, 'loss': -auc_score, 'booster': booster.attributes()}

# %%
mlflow.set_experiment(experiment_name='XGB-params')
# runs initial search to assess 25 hyperparameter combinations
with mlflow.start_run(run_name='XGB_Search'):
    best_params = fmin(
        fn=train_model,
        space=search_space,
        algo=tpe.suggest,
        max_evals=25,
        rstate=np.random.default_rng(59),
    )
# Out:
#   0%|          | 0/25 [00:00<?, ?trial/s, best loss=?]
# job exception: Classification metrics can't handle a mix of binary and continuous targets
#   0%|          | 0/25 [00:11<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\ML\ml_projects\customer-churn_prediction\xgb_hyperparameters.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=1'>2</a> # runs initial search to assess 25 hyperparameter combinations
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=2'>3</a> with mlflow.start_run(run_name='XGB_Search'):
# ----> <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=3'>4</a>     best_params = fmin(
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=4'>5</a>         fn=train_model,
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=5'>6</a>         space=search_space,
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=6'>7</a>         algo=tpe.suggest,
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=7'>8</a>         max_evals=25,
#       <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=8'>9</a>         rstate=np.random.default_rng(59),
#      <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000003?line=9'>10</a>     )
#
# File C:\Python Interpreter\lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=582'>583</a> rval.catch_eval_exceptions = catch_eval_exceptions
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=584'>585</a> # next line is where the fmin is actually executed
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=585'>586</a> rval.exhaust()
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=587'>588</a> if return_argmin:
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=588'>589</a>     if len(trials.trials) == 0:
#
# File C:\Python Interpreter\lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=361'>362</a> def exhaust(self):
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=362'>363</a>     n_done = len(self.trials)
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=363'>364</a>     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=364'>365</a>     self.trials.refresh()
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=365'>366</a>     return self
#
# File C:\Python Interpreter\lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=296'>297</a>     time.sleep(self.poll_interval_secs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=297'>298</a> else:
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=298'>299</a>     # -- loop over trials and do the jobs directly
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=299'>300</a>     self.serial_evaluate()
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=301'>302</a> self.trials.refresh()
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=302'>303</a> if self.trials_save_file != "":
#
# File C:\Python Interpreter\lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=175'>176</a> ctrl = base.Ctrl(self.trials, current_trial=trial)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=176'>177</a> try:
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=177'>178</a>     result = self.domain.evaluate(spec, ctrl)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=178'>179</a> except Exception as e:
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/fmin.py?line=179'>180</a>     logger.error("job exception: %s" % str(e))
#
# File C:\Python Interpreter\lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=882'>883</a> else:
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=883'>884</a>     # -- the "work" of evaluating `config` can be written
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=884'>885</a>     #    either into the pyll part (self.expr)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=885'>886</a>     #    or the normal Python part (self.fn)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=886'>887</a>     pyll_rval = pyll.rec_eval(
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=887'>888</a>         self.expr,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=888'>889</a>         memo=memo,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=889'>890</a>         print_node_on_error=self.rec_eval_print_node_on_error,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=890'>891</a>     )
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=891'>892</a>     rval = self.fn(pyll_rval)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=893'>894</a> if isinstance(rval, (float, int, np.number)):
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/hyperopt/base.py?line=894'>895</a>     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# d:\ML\ml_projects\customer-churn_prediction\xgb_hyperparameters.ipynb Cell 7' in train_model(params)
#      <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000002?line=14'>15</a> # Record AUC as primary loss for Hyperopt to minimize
#      <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000002?line=15'>16</a> predictions_test = booster.predict(test)
# ---> <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000002?line=16'>17</a> f1score = f1_score(y_test, predictions_test)
#      <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000002?line=17'>18</a> mlflow.log_metric('f1-score-mine', f1score)
#      <a href='vscode-notebook-cell:/d%3A/ML/ml_projects/customer-churn_prediction/xgb_hyperparameters.ipynb#ch0000002?line=19'>20</a> auc_score = roc_auc_score(y_test, predictions_test)
#
# File C:\Python Interpreter\lib\site-packages\mlflow\utils\autologging_utils\safety.py:557, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=554'>555</a>     patch_function.call(call_original, *args, **kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=555'>556</a> else:
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=556'>557</a>     patch_function(call_original, *args, **kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=558'>559</a> session.state = "succeeded"
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=560'>561</a> try_log_autologging_event(
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=561'>562</a>     AutologgingEventLogger.get_logger().log_patch_function_success,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=562'>563</a>     session,
#    (...)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=566'>567</a>     kwargs,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=567'>568</a> )
#
# File C:\Python Interpreter\lib\site-packages\mlflow\sklearn\__init__.py:1546, in _autolog.<locals>.patched_metric_api(original, *args, **kwargs)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1541'>1542</a> if _AUTOLOGGING_METRICS_MANAGER.should_log_post_training_metrics():
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1542'>1543</a>     # one metric api may call another metric api,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1543'>1544</a>     # to avoid this, call disable_log_post_training_metrics to avoid nested patch
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1544'>1545</a>     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1545'>1546</a>         metric = original(*args, **kwargs)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1547'>1548</a>     if _AUTOLOGGING_METRICS_MANAGER.is_metric_value_loggable(metric):
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/sklearn/__init__.py?line=1548'>1549</a>         metric_name = original.__name__
#
# File C:\Python Interpreter\lib\site-packages\mlflow\utils\autologging_utils\safety.py:538, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=534'>535</a>         original_result = original(*_og_args, **_og_kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=535'>536</a>         return original_result
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=537'>538</a> return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File C:\Python Interpreter\lib\site-packages\mlflow\utils\autologging_utils\safety.py:473, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=463'>464</a> try:
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=464'>465</a>     try_log_autologging_event(
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=465'>466</a>         AutologgingEventLogger.get_logger().log_original_function_start,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=466'>467</a>         session,
#    (...)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=470'>471</a>         og_kwargs,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=471'>472</a>     )
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=472'>473</a>     original_fn_result = original_fn(*og_args, **og_kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=474'>475</a>     try_log_autologging_event(
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=475'>476</a>         AutologgingEventLogger.get_logger().log_original_function_success,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=476'>477</a>         session,
#    (...)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=480'>481</a>         og_kwargs,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=481'>482</a>     )
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=482'>483</a>     return original_fn_result
#
# File C:\Python Interpreter\lib\site-packages\mlflow\utils\autologging_utils\safety.py:535, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=526'>527</a> # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=527'>528</a> # during original function execution, even if silent mode is enabled
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=528'>529</a> # (`silent=True`), since these warnings originate from the ML framework
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=529'>530</a> # or one of its dependencies and are likely relevant to the caller
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=530'>531</a> with set_non_mlflow_warnings_behavior_for_current_thread(
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=531'>532</a>     disable_warnings=False,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=532'>533</a>     reroute_warnings=False,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=533'>534</a> ):
# --> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=534'>535</a>     original_result = original(*_og_args, **_og_kwargs)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/mlflow/utils/autologging_utils/safety.py?line=535'>536</a>     return original_result
#
# File C:\Python Interpreter\lib\site-packages\sklearn\metrics\_classification.py:1132, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=996'>997</a> def f1_score(
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=997'>998</a>     y_true,
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=998'>999</a>     y_pred,
#    (...)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1004'>1005</a>     zero_division="warn",
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1005'>1006</a> ):
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1006'>1007</a>     """Compute the F1 score, also known as balanced F-score or F-measure.
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1007'>1008</a>
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1008'>1009</a>     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1129'>1130</a>     array([0.66666667, 1.        , 0.66666667])
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1130'>1131</a>     """
# -> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1131'>1132</a>     return fbeta_score(
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1132'>1133</a>         y_true,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1133'>1134</a>         y_pred,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1134'>1135</a>         beta=1,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1135'>1136</a>         labels=labels,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1136'>1137</a>         pos_label=pos_label,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1137'>1138</a>         average=average,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1138'>1139</a>         sample_weight=sample_weight,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1139'>1140</a>         zero_division=zero_division,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1140'>1141</a>     )
#
# File C:\Python Interpreter\lib\site-packages\sklearn\metrics\_classification.py:1270, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1143'>1144</a> def fbeta_score(
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1144'>1145</a>     y_true,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1145'>1146</a>     y_pred,
#    (...)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1152'>1153</a>     zero_division="warn",
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1153'>1154</a> ):
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1154'>1155</a>     """Compute the F-beta score.
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1155'>1156</a>
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1156'>1157</a>     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1266'>1267</a>     array([0.71..., 0.        , 0.        ])
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1267'>1268</a>     """
# -> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1269'>1270</a>     _, _, f, _ = precision_recall_fscore_support(
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1270'>1271</a>         y_true,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1271'>1272</a>         y_pred,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1272'>1273</a>         beta=beta,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1273'>1274</a>         labels=labels,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1274'>1275</a>         pos_label=pos_label,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1275'>1276</a>         average=average,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1276'>1277</a>         warn_for=("f-score",),
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1277'>1278</a>         sample_weight=sample_weight,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1278'>1279</a>         zero_division=zero_division,
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1279'>1280</a>     )
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1280'>1281</a>     return f
#
# File C:\Python Interpreter\lib\site-packages\sklearn\metrics\_classification.py:1556, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1553'>1554</a> if beta < 0:
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1554'>1555</a>     raise ValueError("beta should be >=0 in the F-beta score")
# -> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1555'>1556</a> labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1557'>1558</a> # Calculate tp_sum, pred_sum, true_sum ###
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1558'>1559</a> samplewise = average == "samples"
#
# File C:\Python Interpreter\lib\site-packages\sklearn\metrics\_classification.py:1357, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1353'>1354</a> if average not in average_options and average != "binary":
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1354'>1355</a>     raise ValueError("average has to be one of " + str(average_options))
# -> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1356'>1357</a> y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1357'>1358</a> # Convert to Python primitive type to avoid NumPy type / Python str
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1358'>1359</a> # comparison. See https://github.com/numpy/numpy/issues/6784
#    <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=1359'>1360</a> present_labels = unique_labels(y_true, y_pred).tolist()
#
# File C:\Python Interpreter\lib\site-packages\sklearn\metrics\_classification.py:93, in _check_targets(y_true, y_pred)
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=89'>90</a>     y_type = {"multiclass"}
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=91'>92</a> if len(y_type) > 1:
# ---> <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=92'>93</a>     raise ValueError(
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=93'>94</a>         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=94'>95</a>             type_true, type_pred
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=95'>96</a>         )
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=96'>97</a>     )
#      <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=98'>99</a> # We can't have more than one value on y_type => The set is no more needed
#     <a href='file:///c%3A/Python%20Interpreter/lib/site-packages/sklearn/metrics/_classification.py?line=99'>100</a> y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
